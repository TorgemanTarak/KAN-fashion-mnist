# %%
pip install patool
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 3.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import patoolib
patoolib.extract_archive("dataset.rar", outdir="dataset")
# Out:
# INFO patool: Extracting dataset.rar ...
# ---------------------------------------------------------------------------
# PatoolError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import patoolib
# ----> 2 patoolib.extract_archive("dataset.rar", outdir="dataset")
#
# File ~/miniforge3/envs/agent4/lib/python3.10/site-packages/patoolib/__init__.py:794, in extract_archive(archive, verbosity, outdir, program, interactive, password)
#     792 if verbosity >= 0:
#     793     log.log_info(f"Extracting {archive} ...")
# --> 794 return _extract_archive(archive, verbosity=verbosity, interactive=interactive, outdir=outdir, program=program, password=password)
#
# File ~/miniforge3/envs/agent4/lib/python3.10/site-packages/patoolib/__init__.py:562, in _extract_archive(archive, verbosity, interactive, outdir, program, format, compression, password)
#     560     format, compression = get_archive_format(archive)
# ...

# %%
# !python main.py --nn_type kan --max_iters 100
# Out:
# /home/mohamedt/miniforge3/envs/agent4/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# model running on device : cuda:0
# ...
# Layer (type:depth-idx)                   Param #
# ...
# KAN                                      --
# ├─ModuleList: 1-1                        --
# │    └─KANLinear: 2-1                    501,760
# │    │    └─SiLU: 3-1                    --
# │    └─KANLinear: 2-2                    6,400
# │    │    └─SiLU: 3-2                    --
# ...
# Total params: 508,160
# Trainable params: 508,160
# Non-trainable params: 0
# ...
# data and labels are on
# cuda:0
# cuda:0
# Epoch [1/100], Step [1/750], Loss: 2.2981
# Epoch [1/100], Step [11/750], Loss: 2.3001
# Epoch [1/100], Step [21/750], Loss: 2.2994
# Epoch [1/100], Step [31/750], Loss: 2.2849
# Epoch [1/100], Step [41/750], Loss: 2.2797
# ...
